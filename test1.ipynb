# %%
from matplotlib import pyplot as plt
plt.plot([6,3,4,0],'o')

# %%
plt.plot([2,4,5],[3,4,6],'p')
#'o'representative圆点
# 'd'representative菱形
# 'p'representative六边形
plt.axis([0,6,0,7])
#[xmin,xmax,ymin,ymax]x和y轴的取值范围
plt.title('my first plot')#设置标题
plt.show()
